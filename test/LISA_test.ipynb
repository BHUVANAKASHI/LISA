# %% [markdown]
# # Import LISASensitivity

# %%
from LISA import LISASensitivity as LS

# %% [markdown]
# ## Observation time opts:
# ##### 1. "6mo"
# ##### 2. "1yr"
# ##### 3. "2yr"
# ##### 4. "4yr"

# %%
lisa = LS(observation_time="1yr")

# %% [markdown]
# ## For frequencies and asd use get.data()

# %%
frequencies, asd = lisa.get_data()

# %%
frequencies
# Out:
# array([1.00000000e-05, 1.01159111e-05, 1.02331658e-05, 1.03517796e-05,
#        1.04717682e-05, 1.05931476e-05, 1.07159340e-05, 1.08401436e-05,
#        1.09657929e-05, 1.10928986e-05, 1.12214777e-05, 1.13515471e-05,
#        1.14831241e-05, 1.16162263e-05, 1.17508713e-05, 1.18870770e-05,
#        1.20248614e-05, 1.21642429e-05, 1.23052400e-05, 1.24478715e-05,
#        1.25921561e-05, 1.27381132e-05, 1.28857621e-05, 1.30351224e-05,
#        1.31862140e-05, 1.33390569e-05, 1.34936714e-05, 1.36500781e-05,
#        1.38082977e-05, 1.39683512e-05, 1.41302599e-05, 1.42940453e-05,
#        1.44597292e-05, 1.46273336e-05, 1.47968806e-05, 1.49683929e-05,
#        1.51418933e-05, 1.53174046e-05, 1.54949504e-05, 1.56745541e-05,
#        1.58562396e-05, 1.60400311e-05, 1.62259529e-05, 1.64140297e-05,
#        1.66042866e-05, 1.67967487e-05, 1.69914417e-05, 1.71883914e-05,
#        1.73876240e-05, 1.75891659e-05, 1.77930439e-05, 1.79992851e-05,
# ...

# %%
asd
# Out:
# array([4.44128463e-14, 4.29039508e-14, 4.14463274e-14, 4.00382335e-14,
#        3.86779863e-14, 3.73639597e-14, 3.60945831e-14, 3.48683393e-14,
#        3.36837624e-14, 3.25394367e-14, 3.14339943e-14, 3.03661140e-14,
#        2.93345192e-14, 2.83379771e-14, 2.73752963e-14, 2.64453264e-14,
#        2.55469556e-14, 2.46791104e-14, 2.38407533e-14, 2.30308823e-14,
#        2.22485294e-14, 2.14927596e-14, 2.07626695e-14, 2.00573864e-14,
#        1.93760675e-14, 1.87178984e-14, 1.80820924e-14, 1.74678896e-14,
#        1.68745560e-14, 1.63013823e-14, 1.57476836e-14, 1.52127980e-14,
#        1.46960862e-14, 1.41969308e-14, 1.37147351e-14, 1.32489229e-14,
#        1.27989373e-14, 1.23642407e-14, 1.19443135e-14, 1.15386538e-14,
#        1.11467768e-14, 1.07682141e-14, 1.04025134e-14, 1.00492376e-14,
#        9.70796449e-15, 9.37828620e-15, 9.05980877e-15, 8.75215157e-15,
#        8.45494695e-15, 8.16783972e-15, 7.89048678e-15, 7.62255668e-15,
# ...

# %% [markdown]
# ## Plotting LISA Sensitivity Curve

# %%
lisa.plot()

# %% [markdown]
# ## For sqrt of Sn_total

# %%
lisa.compute_sensitivity()
# Out:
# array([4.44128463e-14, 4.29039508e-14, 4.14463274e-14, 4.00382335e-14,
#        3.86779863e-14, 3.73639597e-14, 3.60945831e-14, 3.48683393e-14,
#        3.36837624e-14, 3.25394367e-14, 3.14339943e-14, 3.03661140e-14,
#        2.93345192e-14, 2.83379771e-14, 2.73752963e-14, 2.64453264e-14,
#        2.55469556e-14, 2.46791104e-14, 2.38407533e-14, 2.30308823e-14,
#        2.22485294e-14, 2.14927596e-14, 2.07626695e-14, 2.00573864e-14,
#        1.93760675e-14, 1.87178984e-14, 1.80820924e-14, 1.74678896e-14,
#        1.68745560e-14, 1.63013823e-14, 1.57476836e-14, 1.52127980e-14,
#        1.46960862e-14, 1.41969308e-14, 1.37147351e-14, 1.32489229e-14,
#        1.27989373e-14, 1.23642407e-14, 1.19443135e-14, 1.15386538e-14,
#        1.11467768e-14, 1.07682141e-14, 1.04025134e-14, 1.00492376e-14,
#        9.70796449e-15, 9.37828620e-15, 9.05980877e-15, 8.75215157e-15,
#        8.45494695e-15, 8.16783972e-15, 7.89048678e-15, 7.62255668e-15,
# ...
